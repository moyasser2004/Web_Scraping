# %%
import requests
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
Country = 'Hong+Kong'
job = 'data+science'
url = "https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
j_t = soup.find_all("h2",class_="css-m604qf")
for i in j_t:
    print(i.text)
# Out:
# Machine Learning Lead
# AI and Machine Learning Engineer
# Data Scientist & AI Specialist (NLP, AI, Business Intelligence)
# AI Engineer
# Senior Data Analyst & Machine Learning Specialist (Full time Remote)
# DevOps Engineer
# Research And Development Specialist
# AI Engineer
# Software Developer (Computer Vision AI-Based Applications)
# AI Engineer
# AI/ML Python Developer
# Senior AI Engineer
# AI Engineer – Digital Transformation
# Maintenance Technician
# Senior Analytics Developer

# %%
loc = soup.find_all("span",class_="css-5wys0k")
for i in loc:
    print(i.text)
# Out:
# Maadi, Cairo, Egypt
# Sheraton, Cairo, Egypt
# Cairo, Egypt
# Heliopolis, Cairo, Egypt
# Cairo, Egypt
# Heliopolis, Cairo, Egypt
# Cairo, Egypt
# Heliopolis, Cairo, Egypt
# Cairo, Egypt
# Cairo, Egypt
# Riyadh, Saudi Arabia
# Cairo, Egypt
# Nasr City, Cairo, Egypt
# Dar Alsalam, Cairo, Egypt
# Maadi, Cairo, Egypt

# %%
company = soup.find_all("a",class_="css-17s97q8")
for i in company:
    print(i.text)
# Out:
# WUZZUF -
# Barkotel -
# Copad Pharma  -
# Confidential -
# HIGHBASE TRADING W.L.L -
# 34ML -
# Confidential -
# Platinum Services Oxford -
# Confidential -
# Rehabitaire -
# BrainBox -
# RMG -
# Tafeel -
# Confidential -
# Xceed Contact Center -

# %%
date = soup.find_all("div",class_="css-do6t5g") 
for i in date:
    print(i.text)

# %%
job_type = soup.find_all("span",class_="css-1ve4b75") 
for i in job_type:
    print(i.text)

# %%
jobs_urls = []
urls = soup.find_all("h2",class_="css-m604qf")
for i in urls:
    jobs_urls.append(i.find('a').attrs['href'])
    print(i.find('a').attrs['href'])
# Out:
# https://wuzzuf.net/jobs/p/4Nf60vomcxgU-Machine-Learning-Lead-WUZZUF-Cairo-Egypt
# https://wuzzuf.net/jobs/p/guAMdmjr881f-AI-and-Machine-Learning-Engineer-Barkotel-Cairo-Egypt
# https://wuzzuf.net/jobs/p/yXQyuPZIsOTQ-Data-Scientist-AI-Specialist-NLP-AI-Business-Intelligence-Copad-Pharma-Cairo-Egypt
# https://wuzzuf.net/jobs/p/6r5WpcPzB8qU-AI-Engineer-Cairo-Egypt
# https://wuzzuf.net/jobs/p/SqMEOhLiBPcT-Senior-Data-Analyst-Machine-Learning-Specialist-Full-time-Remote-HIGHBASE-TRADING-W-L-L-Cairo-Egypt
# https://wuzzuf.net/jobs/p/VQ1SNsUhy28P-DevOps-Engineer-34ML-Cairo-Egypt
# https://wuzzuf.net/jobs/p/GdSWqxkfvoRn-Research-And-Development-Specialist-Cairo-Egypt
# https://wuzzuf.net/jobs/p/BZCbTRuge32V-AI-Engineer-Platinum-Services-Oxford-Cairo-Egypt
# https://wuzzuf.net/jobs/p/ifPtWWn70LCS-Software-Developer-Computer-Vision-AI-Based-Applications-Cairo-Egypt
# https://wuzzuf.net/jobs/p/Xu4wzCQcUFb8-AI-Engineer-Rehabitaire-Cairo-Egypt
# ...

# %%
url = "https://wuzzuf.net/jobs/p/5NFxSMKMH5K0-SeniorMid-Senior-Deep-Learning-Engineer-Cairo-Egypt?o=1&l=sp&t=sj&a=machine%20learning|search-v3|spbg"
page = requests.get(url)
soup = BeautifulSoup(page.content, "lxml")
print(soup.title.text)
# Out:
# 8,626 Job Opportunities in Egypt - Apply Today!

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">8,626 Job Opportunities in Egypt - Apply Today!</title>
# ...

# %%
for url in jobs_urls[0:3]:
    url = url.replace(" ","")
    print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    print(soup.title.text)
# Out:
# https://www.bayt.com/en/egypt/jobs/%D8%A3%D8%AE%D8%B5%D8%A7%D8%A6%D9%8A-%D8%A8%D9%86%D9%8A%D8%A9-%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA-%D9%84%D9%84%D8%B9%D9%85%D9%84-%D8%A8%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-5221652/
# أخصائي بنية بيانات للعمل بالسعودية at شركة البدوي للتوظيف/ Albadwy Recruitment - Cairo - Bayt.com
# https://www.bayt.com/en/egypt/jobs/data-scientist-analyst-72341779/
# Data Scientist Analyst at VISA - Cairo - Bayt.com
# https://www.bayt.com/en/egypt/jobs/network-data-scientist-vois-72335437/
# Network Data Scientist (VOIS) at Vodafone - Egypt - Cairo - Bayt.com

# %% [markdown]
# ### bayt

# %%
url = "https://www.bayt.com/en/egypt/jobs/data-science-jobs/"
page = requests.get(url,headers={'User-Agent': 'Mozilla/5.0'})
soup = BeautifulSoup(page.content, "html.parser")
print(soup.title.text)
# Out:
# Data Science Jobs in Egypt (Feb 2025) - Bayt.com

# %%
title = soup.find_all("h2",class_= "m0")
for j in title:
    print(j.text.strip())
# Out:
# أخصائي بنية بيانات للعمل بالسعودية
# Data Scientist Analyst
# Network Data Scientist (VOIS)
# Data Scientist (Operations Research & ML)
# Data Scientist-Artificial Intelligence
# Senior Azure Data Science Engineer
# Network Data Scientist VOIS
# Senior NW Data Scientist - VOIS
# Expert Data Scientist VOIS
# Senior Data Scientist - 218200
# Data Scientist
# Data Scientist
# Data Science Engineer (Java Stack)
# Team Lead Data Scientist
# Data Scientist
# Mid/Senior - Data Scientist
# Mid-Senior Data Scientist & AI/ML Engineer
# SENIOR DATA SCIENTIST
# Senior Data Scientist - Jumia (Full Time)
# Senior Data Scientist at Teradata

# %%
jobs_urls = []
urls = soup.find_all("h2",class_="m0")
for i in urls:
    jobs_urls.append("https://www.bayt.com"+i.find('a').attrs['href'])
    #print(i.find('a').attrs['href'])
print(jobs_urls)
# Out:
# ['https://www.bayt.com/en/egypt/jobs/%D8%A3%D8%AE%D8%B5%D8%A7%D8%A6%D9%8A-%D8%A8%D9%86%D9%8A%D8%A9-%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA-%D9%84%D9%84%D8%B9%D9%85%D9%84-%D8%A8%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-5221652/', 'https://www.bayt.com/en/egypt/jobs/data-scientist-analyst-72341779/', 'https://www.bayt.com/en/egypt/jobs/network-data-scientist-vois-72335437/', 'https://www.bayt.com/en/egypt/jobs/data-scientist-operations-research-ml-72332196/', 'https://www.bayt.com/en/egypt/jobs/data-scientist-artificial-intelligence-72315001/', 'https://www.bayt.com/en/egypt/jobs/senior-azure-data-science-engineer-72311699/', 'https://www.bayt.com/en/egypt/jobs/network-data-scientist-vois-72309415/', 'https://www.bayt.com/en/egypt/jobs/senior-nw-data-scientist-vois-72309394/', 'https://www.bayt.com/en/egypt/jobs/expert-data-scientist-vois-72281039/', 'https://www.bayt.com/en/egypt/jobs/senior-data-scientist-218200-72264504/', 'https://www.bayt.com/en/egypt/jobs/data-scientist-72257
# ...

# %% [markdown]
# # Quize

# %%
# Find the location
location = soup.find_all("div",class_ ="css-d7j1kk")
for l in location:
    print(l.text)
# Out:
# WUZZUF - Maadi, Cairo, Egypt 2 days ago
# Barkotel - Sheraton, Cairo, Egypt 18 days ago
# Copad Pharma  - Cairo, Egypt 4 days ago
# Confidential - Heliopolis, Cairo, Egypt 1 day ago
# HIGHBASE TRADING W.L.L - Cairo, Egypt 2 months ago
# 34ML - Heliopolis, Cairo, Egypt 4 days ago
# Confidential - Cairo, Egypt 21 days ago
# Platinum Services Oxford - Heliopolis, Cairo, Egypt 23 days ago
# Confidential - Cairo, Egypt 25 days ago
# Rehabitaire - Cairo, Egypt 2 months ago
# BrainBox - Riyadh, Saudi Arabia 2 months ago
# RMG - Cairo, Egypt 19 days ago
# Tafeel - Nasr City, Cairo, Egypt 9 days ago
# Confidential - Dar Alsalam, Cairo, Egypt 23 hours ago
# Xceed Contact Center - Maadi, Cairo, Egypt 14 days ago

# %%
# Find the company
company = soup.find_all("div", class_ ="css-d7j1kk")
for c in company:
    print(c.find("a").text.replace("-", ""))
# Out:
# WUZZUF
# Barkotel
# Copad Pharma
# Confidential
# HIGHBASE TRADING W.L.L
# 34ML
# Confidential
# Platinum Services Oxford
# Confidential
# Rehabitaire
# BrainBox
# RMG
# Tafeel
# Confidential
# Xceed Contact Center

# %%
# job descreption
desc = soup.find_all("div", class_ ="css-y4udm8")
for d in desc:
    print(d.text)
# Out:
# Full TimeHybridManager · 7 - 10 Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · Algorithms · Communication · Communication skills · Computer Science · Elasticsearch · Information Technology (IT) · learning
# Full TimeHybridEntry Level · IT/Software Development · Sales/Retail · Engineering - Telecom/Technology · Computer Vision · Data Analytics · Machine Learning · Artificial Intelligence (AI) · Software Engineering · Programming · Computer Science
# Full TimeOn-siteExperienced · 5+ Yrs of Exp · IT/Software Development · AI · Algorithms · Data Science · Machine Learning · Analysis · NLP · Python · PyTorch · NumPy
# Full TimePart TimeFreelance / ProjectRemoteEntry Level · 1 - 3 Yrs of Exp · IT/Software Development · Analyst/Research · AI · Analysis · Algorithms · Computer Science · Data Analysis · Data · Development · Engineering
# ...
